# %% [markdown]
# <div style="text-align: center; padding: 35px; background-color: #f5f7fa; border-radius: 16px; box-shadow: 0px 6px 14px rgba(0,0,0,0.1); margin-bottom: 30px;">
#
#   <h1 style="color: #2c3e50; font-family: 'Helvetica Neue', sans-serif; font-size: 40px; margin-bottom: 10px;">
#     NMDA Receptor NR1 Subunit <br> Structural Project Index
#   </h1>
#
#   <h3 style="color: #7f8c8d; font-family: 'Georgia', serif; font-weight: normal; font-size: 22px; margin-top: 0;">
#     Directory of Structural Questions and Analyses
#   </h3>
#
#   <p style="color: #34495e; font-family: 'Arial', sans-serif; font-size: 16px; margin-top: 20px;">
#     Author: <b>Vallari Eastman</b><br>
#     Date: <b>October 2025</b>
#   </p>
# </div>

# %% [markdown]
# <div style="background-color:#eef3f6; padding:25px; border-radius:12px; box-shadow:0px 4px 8px rgba(0,0,0,0.08);">
#
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:28px; margin-bottom:20px;">
#     Overview:
#   </h2>
# <p style="text-indent:30px; color: #34495e; font-family: 'Arial', sans-serif; font-size: 15px; margin-top: 18px; line-height:1.6;">
#     This notebook serves as a <b>navigation hub</b> for the structural bioinformatics analyses addressing key questions about the NMDA receptor NR1 subunit.
# Each linked notebook explores one structural hypothesis, along with its methods, figures, and analysis.

# %% [markdown]
# <div style="background-color:#f8f9fb; padding:25px; border-radius:12px; box-shadow:0px 4px 8px rgba(0,0,0,0.08);">
#
#   <h1 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:36px; margin-bottom:15px; text-align:center;">
#     Structural Questions
#   </h1>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This section provides direct access to each structural analysis notebook focused on the NMDA receptor NR1 subunit.
#     Each question explores a specific structural mechanism, combining computational methods, figures, and interpretation.
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#
#   <!-- Q1 -->
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:17px; margin-bottom:10px;">
#     Q1: What can φ (phi) and ψ (psi) dihedral angle analysis of the ligand-binding domain (LBD) reveal about conformational changes in NR1 between agonist- and antagonist-bound states?
#   </h2>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This notebook quantifies backbone dihedral shifts in the NR1 LBD to identify hinge residues that mediate clamshell-like domain closure upon ligand binding.
#   </p>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; margin-top:10px; line-height:1.6;">
#     <b>Open notebook:</b> <a href="NR1_LBD_Dihedrals.ipynb" style="color:#2980b9; text-decoration:none;">NR1_LBD_Dihedrals.ipynb</a>
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#   <!-- Q2 -->
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:17px; margin-bottom:10px;">
#     Q2: How can solvent-accessible surface area profiling, combined with comparative structural modeling, be used to predict and characterize epitope-exposed surfaces on NMDA NR1?
#   </h2>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This notebook performs solvent-accessible surface area (SASA) profiling and comparative structural modeling of the NR1 amino-terminal domain (ATD) to identify and characterize surface-exposed regions that may correspond to antibody-accessible epitopes.
#   </p>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; margin-top:10px; line-height:1.6;">
#     <b>Open notebook:</b> <a href="NR1_Epitopes_SASA.ipynb" style="color:#2980b9; text-decoration:none;">NR1_Epitopes_SASA.ipynb</a>
#   </p>
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#
#   <!-- Q3 -->
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:17px; margin-bottom:10px;">
#     Q3: What can homology modeling of NR1’s ATD across vertebrates reveal about conserved epitopes targeted by anti-NMDAR antibodies?
#   </h2>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This notebook performs multi-species homology modeling and conservation mapping of the NR1 amino-terminal domain (ATD), highlighting surface-exposed residues corresponding to clinically relevant antibody epitopes.
#   </p>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; margin-top:10px; line-height:1.6;">
#     <b>Open notebook:</b> <a href="NR1_ATD_Homology.ipynb" style="color:#2980b9; text-decoration:none;">NR1_ATD_Homology.ipynb</a>
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
# </div>

# %% [markdown]
# <div style="background-color:#f8f9fb; padding:25px; border-radius:12px; box-shadow:0px 4px 8px rgba(0,0,0,0.08);">
#
#   <h1 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:36px; margin-bottom:15px; text-align:center;">
#     Functional Questions
#   </h1>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This section provides direct access to each functional analysis notebook focused on the NMDA receptor NR1 subunit.
#     Each question explores a specific functions, combining computational methods, figures, and interpretation.
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#
# <!-- Q4 -->
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:17px; margin-bottom:10px;">
#     Q4: Which NR1 residues occupy network “bridge” roles connecting the LBD hinge to the transmembrane gate in static structures?
#   </h2>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     This notebook constructs residue-level interaction networks to identify high-centrality “bridge” residues that may transmit
#     mechanical signals between the ligand-binding domain and the transmembrane gate during activation.
#   </p>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; margin-top:10px; line-height:1.6;">
#     <b>Open notebook:</b> <a href="NR1_Bridge_Networks" style="color:#2980b9; text-decoration:none;">NR1_Bridge_Networks</a>
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#
#   <!-- Q2 -->
#   <h2 style="color:#2c3e50; font-family:'Helvetica Neue',sans-serif; font-size:17px; margin-bottom:10px;">
#     Q2: TBD
#   </h2>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; line-height:1.6;">
#     TBD
#   </p>
#
#   <p style="text-indent:30px; color:#34495e; font-family:'Arial',sans-serif; font-size:15px; margin-top:10px; line-height:1.6;">
#     <b>Open notebook:</b> <a href="NR1_ATD_Homology.ipynb" style="color:#2980b9; text-decoration:none;">NR1_ATD_Homology.ipynb</a>
#   </p>
#
#   <hr style="border:none; border-top:1px solid #d6dbdf; margin:25px 0;">
#
# </div>

# %% [markdown]
# <div style="text-align:center; background-color:#eef3f6; padding:18px; border-radius:10px; margin-top:40px;">
#   <h3 style="font-family:'Georgia',serif; color:#2c3e50;">Navigation Notes</h3>
#   <p style="font-family:'Arial',sans-serif; color:#34495e;">
#     Each linked notebook is modular and executable independently.<br>
#     Shared utilities (e.g., φ/ψ calculator, DSSP parser, contact-map generator) are stored in <code>utils/</code>.<br>
#     All structural files (PDBs, models, and alignments) are located under <code>data/</code>.
#   </p>
# </div>
